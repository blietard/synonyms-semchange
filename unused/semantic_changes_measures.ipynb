# %% [markdown]
# # Measuring Semantic Change

# %%
import pickle
from tqdm import tqdm
import os

import scipy.sparse as sp
import numpy as np
import pandas as pd

# %%
pos = 'V'
suffix = 'doubNorm_cosine/'
NN_FOLDER = './nearest_neighbors/'+suffix

DECADES = list(range(1890,2000,10))

# %%
if pos.lower() in ['a','adj','adjective']:
    pos = 'A'
    with open('./words/adjs_list.pickle','rb') as f:
        word_list = pickle.load(f)
elif pos.lower() in ['n','noun']:
    pos = 'N'
    with open('./words/nouns_list.pickle','rb') as f:
        word_list = pickle.load(f)
elif pos.lower() in ['v','verb']:
    pos = 'V'
    with open('./words/verbs_list.pickle','rb') as f:
        word_list = pickle.load(f)
else:
    raise ValueError('Invalid POS tag value : ' + pos)

word2ind = {word : i for i,word in enumerate(word_list)}

# %% [markdown]
# ## Generating the dataframe

# %%
semChange = pd.DataFrame(columns=DECADES,dtype='float16',index = word_list )
semChange.index.name = 'words'
semChange[1890] = np.zeros(len(word_list))
semChange
# Out:
#             1890  1900  1910  1920  1930  1940  1950  1960  1970  1980  1990
# words
# abandon      0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# abandoned    0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# abandoning   0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# abandons     0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# abate        0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# zeitung      0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# zigzagged    0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# zigzagging   0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# zipped       0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# zipping      0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [8357 rows x 11 columns]

# %%
files = os.listdir(NN_FOLDER)
available_decades = []
for f in files:
    fname = f.replace('.npy','') #remove .npy
    f_dec, f_pos = fname.split('_')
    if f_pos == pos:
        available_decades.append(int(f_dec))
if 1890 not in available_decades:
    raise FileNotFoundError('No file for the origin decade 1890.')
print(available_decades)
available_decades.pop( available_decades.index(1890) )
# Out:
# [1890, 1990]
# 1890

# %%
nn_origin_array = np.load(NN_FOLDER+f'{1890}_{pos}.npy')
for decade in available_decades:
    nn_array = np.load(NN_FOLDER+f'{decade}_{pos}.npy')
    k = 100
    target_change = np.empty(len(word_list))
    for i in range(len(word_list)):
        nn_origin = nn_origin_array[i][:k]
        nn_target = nn_array[i][:k]
        intersect = np.intersect1d(nn_origin,nn_target)
        sc_target = 1-len(intersect)/len(nn_origin)
        target_change[i] = sc_target
    print(decade,'Average change : ', target_change.mean().round(4))
    print(decade,'Std Dev. of change: ', target_change.std().round(4))
    semChange[ decade ] = target_change.copy()
# Out:
# 1990 Average change :  0.779
# 1990 Std Dev. of change:  0.1203

# %%
semChange
# Out:
#             1890  1900  1910  1920  1930  1940  1950  1960  1970  1980  1990
# words
# abandon      0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  0.73
# abandoned    0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  0.69
# abandoning   0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  0.77
# abandons     0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  0.81
# abate        0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  0.92
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# zeitung      0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  0.68
# zigzagged    0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  0.78
# zigzagging   0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  0.72
# zipped       0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  0.83
# zipping      0.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  1.00
#
# [8357 rows x 11 columns]

# %%
semChange.to_csv(f'./semantic_change_measures/{suffix}/{pos}.csv', sep='\t',index=True)

# %% [markdown]
# ## A bit of exploration

# %%
[(word_list[i],target_change[i].round(3)) for i in np.argsort(target_change)]
# Out:
# [('reddish', 0.19),
#  ('dark', 0.21),
#  ('even', 0.21),
#  ('dutch', 0.21),
#  ('grey', 0.21),
#  ('old', 0.21),
#  ('silvery', 0.21),
#  ('ly', 0.22),
#  ('persian', 0.22),
#  ('burnt', 0.22),
#  ('afraid', 0.22),
#  ('still', 0.23),
#  ('green', 0.23),
#  ('burning', 0.23),
#  ('blue', 0.23),
#  ('away', 0.23),
#  ('prepared', 0.24),
#  ('frightened', 0.24),
#  ('occasional', 0.24),
#  ('lustrous', 0.24),
#  ('shining', 0.24),
#  ('grayish', 0.24),
#  ('shiny', 0.24),
#  ("ev'ry", 0.25),
#  ('saxon', 0.25),
#  ('resolute', 0.25),
#  ('near', 0.25),
#  ('stout', 0.25),
#  ('swift', 0.25),
#  ('greenish', 0.25),
#  ('greyish', 0.25),
#  ('shamed', 0.26),
#  ('blackened', 0.26),
#  ('blind', 0.26),
#  ('well', 0.26),
#  ('turkish', 0.26),
#  ('cool', 0.26),
#  ('dauntless', 0.26),
#  ('alone', 0.26),
#  ('sloping', 0.26),
#  ('obliging', 0.26),
#  ('whitish', 0.26),
#  ('arrant', 0.26),
#  ('greasy', 0.26),
#  ('chinese', 0.27),
#  ('small', 0.27),
#  ('snowy', 0.27),
#  ('soft', 0.27),
#  ('stiff', 0.27),
#  ('right', 0.27),
#  ('cold', 0.27),
#  ('innocent', 0.27),
#  ('red', 0.27),
#  ('wee', 0.27),
#  ('inscribed', 0.27),
#  ('undaunted', 0.27),
#  ('grassy', 0.27),
#  ('unswerving', 0.27),
#  ('new', 0.28),
#  ('swiss', 0.28),
#  ('cloudy', 0.28),
#  ('canadian', 0.28),
#  ('outer', 0.28),
#  ('afflicted', 0.28),
#  ('slanting', 0.28),
#  ('coloured', 0.28),
#  ('whitest', 0.28),
#  ('phoenician', 0.28),
#  ('gray', 0.28),
#  ('reconciled', 0.28),
#  ('native', 0.28),
#  ('hairy', 0.28),
#  ('inky', 0.28),
#  ('perplexed', 0.28),
#  ('darkish', 0.28),
#  ('velvety', 0.28),
#  ('spiny', 0.28),
#  ('unshaken', 0.28),
#  ('gratified', 0.29),
#  ('cuban', 0.29),
#  ('busy', 0.29),
#  ('ordinary', 0.29),
#  ('rich', 0.29),
#  ('shadowed', 0.29),
#  ('sole', 0.29),
#  ('early', 0.29),
#  ('large', 0.29),
#  ('christian', 0.29),
#  ('alarmed', 0.29),
#  ('luminous', 0.29),
#  ('unutterable', 0.29),
#  ('ribbed', 0.29),
#  ('southern', 0.29),
#  ('official', 0.29),
#  ('darker', 0.29),
#  ('ready', 0.29),
#  ('fringed', 0.29),
#  ('undeserved', 0.29),
#  ('straight', 0.29),
#  ('scottish', 0.29),
#  ('grave', 0.29),
#  ('stoical', 0.29),
#  ('sharp', 0.29),
#  ('grievous', 0.29),
#  ('moist', 0.29),
#  ('inconsiderable', 0.29),
#  ('shaggy', 0.29),
#  ('rebuilt', 0.3),
#  ('reckless', 0.3),
#  ('recalcitrant', 0.3),
#  ('savage', 0.3),
#  ('livid', 0.3),
#  ('alive', 0.3),
#  ('unwavering', 0.3),
#  ('shaded', 0.3),
#  ('japanese', 0.3),
#  ('grand', 0.3),
#  ('unwilling', 0.3),
#  ('printed', 0.3),
#  ('magnanimous', 0.3),
#  ('principal', 0.3),
#  ('blessed', 0.3),
#  ('brown', 0.3),
#  ('unappeasable', 0.3),
#  ('unconverted', 0.3),
#  ('baggy', 0.3),
#  ('powdered', 0.3),
#  ('tinted', 0.3),
#  ('young', 0.3),
#  ('oily', 0.3),
#  ('tiny', 0.3),
#  ('monastic', 0.3),
#  ('bloodthirsty', 0.31),
#  ('shady', 0.31),
#  ('darkling', 0.31),
#  ('frequent', 0.31),
#  ('flemish', 0.31),
#  ('hal', 0.31),
#  ('blackish', 0.31),
#  ('speckled', 0.31),
#  ('sheer', 0.31),
#  ('cupid', 0.31),
#  ('unflinching', 0.31),
#  ('florentine', 0.31),
#  ('male', 0.31),
#  ('unsympathetic', 0.31),
#  ('westward', 0.31),
#  ('maddened', 0.31),
#  ('present', 0.31),
#  ('observant', 0.31),
#  ('innumerable', 0.31),
#  ('timid', 0.31),
#  ('great', 0.31),
#  ('afterward', 0.31),
#  ('carved', 0.31),
#  ('withered', 0.31),
#  ('fuller', 0.31),
#  ('frolicsome', 0.31),
#  ('swedish', 0.31),
#  ('unquestioning', 0.31),
#  ('oval', 0.31),
#  ('burly', 0.31),
#  ('unclouded', 0.31),
#  ('coarse', 0.31),
#  ('oldest', 0.31),
#  ('bushy', 0.31),
#  ('untutored', 0.31),
#  ('sticky', 0.32),
#  ('awake', 0.32),
#  ('timorous', 0.32),
#  ('commodious', 0.32),
#  ('undiminished', 0.32),
#  ('unsuspecting', 0.32),
#  ('tyrian', 0.32),
#  ('spongy', 0.32),
#  ('bitterest', 0.32),
#  ('yellowish', 0.32),
#  ('unregenerate', 0.32),
#  ('untangled', 0.32),
#  ('unsullied', 0.32),
#  ('lacquered', 0.32),
#  ('shimmering', 0.32),
#  ('natured', 0.32),
#  ('perpetual', 0.32),
#  ('silky', 0.32),
#  ('whiter', 0.32),
#  ('excited', 0.32),
#  ('earliest', 0.32),
#  ('magnificent', 0.32),
#  ('outstretched', 0.32),
#  ('vexed', 0.32),
#  ('roman', 0.32),
#  ('incontrovertible', 0.32),
#  ('dappled', 0.32),
#  ('nearest', 0.32),
#  ('accomplished', 0.33),
#  ('african', 0.33),
#  ('obedient', 0.33),
#  ('oriental', 0.33),
#  ('unbounded', 0.33),
#  ('ultimate', 0.33),
#  ('persecuted', 0.33),
#  ('unconditional', 0.33),
#  ('undulating', 0.33),
#  ('unexpected', 0.33),
#  ('eternal', 0.33),
#  ('little', 0.33),
#  ('lofty', 0.33),
#  ('free', 0.33),
#  ('unquestionable', 0.33),
#  ('white', 0.33),
#  ('ungovernable', 0.33),
#  ('uneducated', 0.33),
#  ('unfeigned', 0.33),
#  ('wet', 0.33),
#  ('momentary', 0.33),
#  ('bleached', 0.33),
#  ('western', 0.33),
#  ('inoffensive', 0.33),
#  ('frightful', 0.33),
#  ('unfaltering', 0.33),
#  ('prejudiced', 0.33),
#  ('rickety', 0.33),
#  ('sardinian', 0.33),
#  ('ridiculous', 0.33),
#  ('colorless', 0.33),
#  ('abundant', 0.33),
#  ('shameless', 0.33),
#  ('saracen', 0.33),
#  ('smooth', 0.33),
#  ('smallest', 0.33),
#  ('colonial', 0.33),
#  ('reserved', 0.33),
#  ('respected', 0.33),
#  ('speechless', 0.33),
#  ('slender', 0.33),
#  ('slippery', 0.33),
#  ('theocratic', 0.33),
#  ('recent', 0.33),
#  ('prodigious', 0.33),
#  ('probable', 0.33),
#  ('alleged', 0.33),
#  ('manufactured', 0.34),
#  ('incessant', 0.34),
#  ('shallow', 0.34),
#  ('manifest', 0.34),
#  ('maimed', 0.34),
#  ('malodorous', 0.34),
#  ('maligned', 0.34),
#  ('awful', 0.34),
#  ('silent', 0.34),
#  ('silken', 0.34),
#  ('smoky', 0.34),
#  ('fragrant', 0.34),
#  ('unreasoning', 0.34),
#  ('larger', 0.34),
#  ('inborn', 0.34),
#  ('splendid', 0.34),
#  ('peruvian', 0.34),
#  ('scythian', 0.34),
#  ('tired', 0.34),
#  ('catholic', 0.34),
#  ('inquisitive', 0.34),
#  ('slightest', 0.34),
#  ('unavailing', 0.34),
#  ('resplendent', 0.34),
#  ('restless', 0.34),
#  ('ole', 0.34),
#  ('older', 0.34),
#  ('bleeding', 0.34),
#  ('insensate', 0.34),
#  ('oblong', 0.34),
#  ('ascertainable', 0.34),
#  ('necessary', 0.34),
#  ('collapsible', 0.34),
#  ('british', 0.34),
#  ('nearer', 0.34),
#  ('comely', 0.34),
#  ('private', 0.34),
#  ('inland', 0.34),
#  ('greater', 0.34),
#  ('slimy', 0.34),
#  ('hardy', 0.34),
#  ('accursed', 0.34),
#  ('whole', 0.34),
#  ('untilled', 0.34),
#  ('venturesome', 0.34),
#  ('unwary', 0.34),
#  ('venomous', 0.34),
#  ('veined', 0.34),
#  ('westernmost', 0.34),
#  ('abused', 0.34),
#  ('obvious', 0.35),
#  ('vertical', 0.35),
#  ('languid', 0.35),
#  ('loyalist', 0.35),
#  ('comfortable', 0.35),
#  ('irish', 0.35),
#  ('neat', 0.35),
#  ('altered', 0.35),
#  ('specious', 0.35),
#  ('woollen', 0.35),
#  ('molten', 0.35),
#  ('possible', 0.35),
#  ('resinous', 0.35),
#  ('veritable', 0.35),
#  ('doughty', 0.35),
#  ('allotted', 0.35),
#  ('round', 0.35),
#  ('circassian', 0.35),
#  ('earthly', 0.35),
#  ('bound', 0.35),
#  ('nearby', 0.35),
#  ('aforesaid', 0.35),
#  ('unmolested', 0.35),
#  ('sleepy', 0.35),
#  ('venerable', 0.35),
#  ('wedded', 0.35),
#  ('initial', 0.35),
#  ('awkward', 0.35),
#  ('innate', 0.35),
#  ('shapely', 0.35),
#  ('wholehearted', 0.35),
#  ('outside', 0.35),
#  ('greatest', 0.35),
#  ('real', 0.35),
#  ('determined', 0.35),
#  ('undisguised', 0.35),
#  ('lamentable', 0.35),
#  ('smaller', 0.35),
#  ('scandinavian', 0.35),
#  ('shiftless', 0.35),
#  ('unsociable', 0.35),
#  ('coldest', 0.35),
#  ('pulpy', 0.35),
#  ('unseemly', 0.35),
#  ('mammoth', 0.35),
#  ('haired', 0.35),
#  ('burnished', 0.35),
#  ('foster', 0.35),
#  ('unbelieving', 0.36),
#  ('socalled', 0.36),
#  ('reprehensible', 0.36),
#  ('undisciplined', 0.36),
#  ('ordained', 0.36),
#  ('sociable', 0.36),
#  ('salable', 0.36),
#  ('avoidable', 0.36),
#  ('inordinate', 0.36),
#  ('slim', 0.36),
#  ('blooded', 0.36),
#  ('unhappy', 0.36),
#  ('artificial', 0.36),
#  ('habitable', 0.36),
#  ('righteous', 0.36),
#  ('civil', 0.36),
#  ('allegorical', 0.36),
#  ('craven', 0.36),
#  ('slight', 0.36),
#  ('restful', 0.36),
#  ('welcome', 0.36),
#  ('silvered', 0.36),
#  ('recessed', 0.36),
#  ('inhospitable', 0.36),
#  ('forward', 0.36),
#  ('eared', 0.36),
#  ('earlier', 0.36),
#  ('inconsiderate', 0.36),
#  ('untracked', 0.36),
#  ('simpering', 0.36),
#  ('straighter', 0.36),
#  ('unenlightened', 0.36),
#  ('american', 0.36),
#  ('sodden', 0.36),
#  ('unconquerable', 0.36),
#  ('weekly', 0.36),
#  ('spanish', 0.36),
#  ('luckless', 0.36),
#  ('colored', 0.36),
#  ('positivistic', 0.36),
#  ('unforeseen', 0.36),
#  ('russian', 0.36),
#  ('unselfish', 0.36),
#  ('hawaiian', 0.36),
#  ('unappreciative', 0.36),
#  ('ceaseless', 0.36),
#  ('greased', 0.36),
#  ('untrue', 0.36),
#  ('alarming', 0.36),
#  ('greedy', 0.36),
#  ('colourless', 0.36),
#  ('specified', 0.36),
#  ('embroidered', 0.36),
#  ('unexampled', 0.36),
#  ('accidental', 0.36),
#  ('blest', 0.36),
#  ('darkened', 0.36),
#  ('good', 0.36),
#  ('slanderous', 0.36),
#  ('frivolous', 0.36),
#  ('unfortunate', 0.36),
#  ('obstinate', 0.36),
#  ('frayed', 0.36),
#  ('soiled', 0.36),
#  ('outermost', 0.37),
#  ('simple', 0.37),
#  ('blasphemous', 0.37),
#  ('commonsense', 0.37),
#  ('unfailing', 0.37),
#  ('accustomed', 0.37),
#  ('verdant', 0.37),
#  ('fresh', 0.37),
#  ('similar', 0.37),
#  ('fraternal', 0.37),
#  ('english', 0.37),
#  ('javanese', 0.37),
#  ('rectangular', 0.37),
#  ('airtight', 0.37),
#  ('outspread', 0.37),
#  ('afghan', 0.37),
#  ('oaken', 0.37),
#  ('sleepless', 0.37),
#  ('unfinished', 0.37),
#  ('enclosed', 0.37),
#  ('largest', 0.37),
#  ('communistic', 0.37),
#  ('striped', 0.37),
#  ('inner', 0.37),
#  ('inlaid', 0.37),
#  ('insatiable', 0.37),
#  ('landward', 0.37),
#  ('french', 0.37),
#  ('undemonstrative', 0.37),
#  ('delighted', 0.37),
#  ('respectful', 0.37),
#  ('socialistic', 0.37),
#  ('requisite', 0.37),
#  ('excessive', 0.37),
#  ('unsightly', 0.37),
#  ('lowest', 0.37),
#  ('unconstitutional', 0.37),
#  ('mannered', 0.37),
#  ('prepossessing', 0.37),
#  ('stoutest', 0.37),
#  ('evergreen', 0.37),
#  ('speedy', 0.37),
#  ('brutish', 0.37),
#  ('carolingian', 0.37),
#  ('continental', 0.37),
#  ('southwestern', 0.37),
#  ('unruly', 0.37),
#  ('respectable', 0.37),
#  ('mad', 0.37),
#  ('greek', 0.37),
#  ('military', 0.37),
#  ('unscrupulous', 0.37),
#  ('untroubled', 0.37),
#  ('grandest', 0.37),
#  ('eventual', 0.37),
#  ('purple', 0.37),
#  ('translucent', 0.37),
#  ('saleable', 0.37),
#  ('undignified', 0.37),
#  ('undeviating', 0.37),
#  ('unbecoming', 0.37),
#  ('tipsy', 0.37),
#  ('inconceivable', 0.37),
#  ('natural', 0.37),
#  ('inclined', 0.37),
#  ('elongated', 0.37),
#  ('public', 0.37),
#  ('habitual', 0.37),
#  ('confucian', 0.37),
#  ('luxuriant', 0.37),
#  ('uncultivated', 0.37),
#  ('philosophic', 0.37),
#  ('evaporated', 0.37),
#  ('awed', 0.37),
#  ('local', 0.37),
#  ('uncut', 0.37),
#  ('philippine', 0.37),
#  ('aware', 0.37),
#  ('splintered', 0.37),
#  ('venial', 0.38),
#  ('sheltered', 0.38),
#  ('far', 0.38),
#  ('crinkly', 0.38),
#  ('italian', 0.38),
#  ('cogent', 0.38),
#  ('farther', 0.38),
#  ('jewish', 0.38),
#  ('mangy', 0.38),
#  ('unchristian', 0.38),
#  ('wellknown', 0.38),
#  ('uncommon', 0.38),
#  ('untoward', 0.38),
#  ('undetermined', 0.38),
#  ('tiresome', 0.38),
#  ('chilean', 0.38),
#  ('westerly', 0.38),
#  ('shapeless', 0.38),
#  ('cherished', 0.38),
#  ('unemployed', 0.38),
#  ('adventurous', 0.38),
#  ('lame', 0.38),
#  ('respective', 0.38),
#  ('damp', 0.38),
#  ('remaining', 0.38),
#  ('devoted', 0.38),
#  ('crocheted', 0.38),
#  ('unconquered', 0.38),
#  ('brutalized', 0.38),
#  ('shaven', 0.38),
#  ('reserve', 0.38),
#  ('bumptious', 0.38),
#  ('unconvincing', 0.38),
#  ('unaccountable', 0.38),
#  ('majestic', 0.38),
#  ('riotous', 0.38),
#  ('solemn', 0.38),
#  ('injured', 0.38),
#  ('stormy', 0.38),
#  ('frilled', 0.38),
#  ('outlying', 0.38),
#  ('earnest', 0.38),
#  ('earthen', 0.38),
#  ('posterior', 0.38),
#  ('plaited', 0.38),
#  ('comical', 0.38),
#  ('untarnished', 0.38),
#  ('alike', 0.38),
#  ('dominican', 0.38),
#  ('ungracious', 0.38),
#  ('gravelled', 0.38),
#  ('divine', 0.38),
#  ('slow', 0.38),
#  ('dearest', 0.38),
#  ('royal', 0.38),
#  ('predetermined', 0.38),
#  ('friable', 0.38),
#  ('spherical', 0.38),
#  ('sociological', 0.38),
#  ('unqualified', 0.38),
#  ('freckled', 0.38),
#  ('baked', 0.38),
#  ('slushy', 0.38),
#  ('bitter', 0.38),
#  ('incalculable', 0.38),
#  ('unfenced', 0.38),
#  ('framed', 0.38),
#  ('black', 0.38),
#  ('unspeakable', 0.38),
#  ('big', 0.38),
#  ('upward', 0.38),
#  ('phrygian', 0.38),
#  ('snaky', 0.38),
#  ('hard', 0.38),
#  ('concave', 0.38),
#  ('spirited', 0.38),
#  ('incontestable', 0.38),
#  ('motionless', 0.39),
#  ('mottled', 0.39),
#  ('unreasonable', 0.39),
#  ('flaky', 0.39),
#  ('roundish', 0.39),
#  ('connected', 0.39),
#  ('venerated', 0.39),
#  ('inadmissible', 0.39),
#  ('uncooked', 0.39),
#  ('exact', 0.39),
#  ('alliterative', 0.39),
#  ('unsuspected', 0.39),
#  ('blameless', 0.39),
#  ('unreserved', 0.39),
#  ('smart', 0.39),
#  ('protected', 0.39),
#  ('high', 0.39),
#  ('unsmiling', 0.39),
#  ('magical', 0.39),
#  ('iberian', 0.39),
#  ('uncivilized', 0.39),
#  ('unshakable', 0.39),
#  ('convinced', 0.39),
#  ('sheerest', 0.39),
#  ('uncombed', 0.39),
#  ('resourceful', 0.39),
#  ('worthy', 0.39),
#  ('associated', 0.39),
#  ('unscientific', 0.39),
#  ('astonished', 0.39),
#  ('predestined', 0.39),
#  ('luscious', 0.39),
#  ('modern', 0.39),
#  ('potential', 0.39),
#  ('unalloyed', 0.39),
#  ('graver', 0.39),
#  ('ludicrous', 0.39),
#  ('unconcealed', 0.39),
#  ('fibrous', 0.39),
#  ('gracious', 0.39),
#  ('gravelly', 0.39),
#  ('sportive', 0.39),
#  ('dangerous', 0.39),
#  ('reproachful', 0.39),
#  ('gelatinous', 0.39),
#  ('airy', 0.39),
#  ('unpleasant', 0.39),
#  ('alienating', 0.39),
#  ('unearthly', 0.39),
#  ('blissful', 0.39),
#  ('obdurate', 0.39),
#  ('common', 0.39),
#  ('shadowless', 0.39),
#  ('verbose', 0.39),
#  ('neatest', 0.39),
#  ('ungrateful', 0.39),
#  ('egyptian', 0.39),
#  ('silly', 0.39),
#  ('ungodly', 0.39),
#  ('ungentlemanly', 0.39),
#  ('comfortless', 0.39),
#  ('sweet', 0.39),
#  ('insolent', 0.39),
#  ('combined', 0.39),
#  ('daring', 0.39),
#  ('bloodstained', 0.39),
#  ('oftenest', 0.39),
#  ('dead', 0.39),
#  ('complacent', 0.39),
#  ('welcoming', 0.39),
#  ('unfeeling', 0.39),
#  ('frantic', 0.39),
#  ('rebellious', 0.39),
#  ('perplexing', 0.39),
#  ('wilder', 0.39),
#  ('inconspicuous', 0.39),
#  ('opalescent', 0.39),
#  ('aforementioned', 0.39),
#  ('original', 0.39),
#  ('stony', 0.39),
#  ('absurd', 0.39),
#  ('ethnological', 0.39),
#  ('unprejudiced', 0.39),
#  ('stouter', 0.39),
#  ('colder', 0.39),
#  ('convicted', 0.4),
#  ('fabian', 0.4),
#  ('anglo', 0.4),
#  ('faster', 0.4),
#  ('supposed', 0.4),
#  ('pronounced', 0.4),
#  ('affirmative', 0.4),
#  ('managerial', 0.4),
#  ('ot', 0.4),
#  ('cardboard', 0.4),
#  ('oligarchic', 0.4),
#  ('amused', 0.4),
#  ('superior', 0.4),
#  ('prescribed', 0.4),
#  ('mauve', 0.4),
#  ('unassailable', 0.4),
#  ('coveted', 0.4),
#  ('manly', 0.4),
#  ('corded', 0.4),
#  ('unavoidable', 0.4),
#  ('prehensile', 0.4),
#  ('startled', 0.4),
#  ('elected', 0.4),
#  ('cherokee', 0.4),
#  ('personal', 0.4),
#  ('sprained', 0.4),
#  ('ageless', 0.4),
#  ('philosophical', 0.4),
#  ('phlegmatic', 0.4),
#  ('transferable', 0.4),
#  ('eventful', 0.4),
#  ('peripatetic', 0.4),
#  ('repulsive', 0.4),
#  ('spiteful', 0.4),
#  ('conservative', 0.4),
#  ('everlasting', 0.4),
#  ('unworthy', 0.4),
#  ('storied', 0.4),
#  ('pink', 0.4),
#  ('excavated', 0.4),
#  ('varied', 0.4),
#  ('monarchical', 0.4),
#  ('theoretical', 0.4),
#  ('quilted', 0.4),
#  ('outward', 0.4),
#  ('reclaimed', 0.4),
#  ('unalterable', 0.4),
#  ('comic', 0.4),
#  ('distinguishable', 0.4),
#  ('convenient', 0.4),
#  ('officious', 0.4),
#  ('timothy', 0.4),
#  ('vengeful', 0.4),
#  ('exasperated', 0.4),
#  ('untruthful', 0.4),
#  ('responsible', 0.4),
#  ('unpopulated', 0.4),
#  ('dastardly', 0.4),
#  ('lusty', 0.4),
#  ('designated', 0.4),
#  ('unquenchable', 0.4),
#  ('incomprehensible', 0.4),
#  ('lustful', 0.4),
#  ('uncomplimentary', 0.4),
#  ('lowermost', 0.4),
#  ('ungainly', 0.4),
#  ('indian', 0.4),
#  ('unjustifiable', 0.4),
#  ('unpromising', 0.4),
#  ('unending', 0.4),
#  ('lumpy', 0.4),
#  ('unprincipled', 0.4),
#  ('untold', 0.4),
#  ('seductive', 0.4),
#  ('accumulated', 0.4),
#  ('scriptural', 0.4),
#  ('curt', 0.4),
#  ('incorporated', 0.4),
#  ('grandiose', 0.4),
#  ('loyal', 0.4),
#  ('unclean', 0.4),
#  ('ungoverned', 0.4),
#  ('increased', 0.4),
#  ('rhymed', 0.4),
#  ('risky', 0.4),
#  ('handiest', 0.4),
#  ('unseen', 0.4),
#  ('select', 0.4),
#  ('blooming', 0.4),
#  ('untidy', 0.4),
#  ('loaded', 0.4),
#  ('blond', 0.4),
#  ('inopportune', 0.4),
#  ('foreign', 0.4),
#  ('graveled', 0.4),
#  ('impracticable', 0.4),
#  ('ridged', 0.4),
#  ('inanimate', 0.4),
#  ('unrequited', 0.4),
#  ('inmost', 0.4),
#  ('malicious', 0.4),
#  ('bad', 0.4),
#  ('uncrowned', 0.4),
#  ('authorized', 0.4),
#  ('lively', 0.4),
#  ('slumbering', 0.41),
#  ('pinkish', 0.41),
#  ('welsh', 0.41),
#  ('unwarranted', 0.41),
#  ('flaxen', 0.41),
#  ('wide', 0.41),
#  ('undisputed', 0.41),
#  ('nauseating', 0.41),
#  ('insipid', 0.41),
#  ('preconceived', 0.41),
#  ('woolly', 0.41),
#  ('unsatisfactory', 0.41),
#  ('greenest', 0.41),
#  ('belgian', 0.41),
#  ('shallower', 0.41),
#  ('valueless', 0.41),
#  ('columned', 0.41),
#  ('late', 0.41),
#  ('woolen', 0.41),
#  ('unrestrained', 0.41),
#  ('blank', 0.41),
#  ('rhyming', 0.41),
#  ('ladylike', 0.41),
#  ('lambent', 0.41),
#  ('blinding', 0.41),
#  ('oldfashioned', 0.41),
#  ('lamplit', 0.41),
#  ('olden', 0.41),
#  ('olde', 0.41),
#  ('close', 0.41),
#  ('unfathomed', 0.41),
#  ('unruffled', 0.41),
#  ('rhetorical', 0.41),
#  ('deserted', 0.41),
#  ('digestible', 0.41),
#  ('combustible', 0.41),
#  ('friendly', 0.41),
#  ('objectionable', 0.41),
#  ('gravest', 0.41),
#  ('obscene', 0.41),
#  ('axiomatic', 0.41),
#  ('northward', 0.41),
#  ('obsequious', 0.41),
#  ('columnar', 0.41),
#  ('obstreperous', 0.41),
#  ('colossal', 0.41),
#  ('freezing', 0.41),
#  ('southward', 0.41),
#  ('bluish', 0.41),
#  ('advisable', 0.41),
#  ('required', 0.41),
#  ('discernible', 0.41),
#  ('gaelic', 0.41),
#  ('maddest', 0.41),
#  ('feathery', 0.41),
#  ('spontaneous', 0.41),
#  ('uncomfortable', 0.41),
#  ('merciful', 0.41),
#  ('unverified', 0.41),
#  ('persistent', 0.41),
#  ('dispersed', 0.41),
#  ('celebrated', 0.41),
#  ('hairless', 0.41),
#  ('pale', 0.41),
#  ('eager', 0.41),
#  ('stockinged', 0.41),
#  ('hindu', 0.41),
#  ('untrimmed', 0.41),
#  ('seemly', 0.41),
#  ('married', 0.41),
#  ('calculable', 0.41),
#  ('philological', 0.41),
#  ('disappointed', 0.41),
#  ('malformed', 0.41),
#  ('untamed', 0.41),
#  ('malevolent', 0.41),
#  ('whimsical', 0.41),
#  ('dry', 0.41),
#  ('unceasing', 0.41),
#  ('phantom', 0.41),
#  ('unvarying', 0.41),
#  ('conical', 0.41),
#  ('snider', 0.41),
#  ('incompetent', 0.41),
#  ('determinable', 0.41),
#  ('unceremonious', 0.41),
#  ('unquestioned', 0.41),
#  ('darkest', 0.41),
#  ('convulsive', 0.41),
#  ('tubby', 0.41),
#  ('purplish', 0.41),
#  ('brocaded', 0.41),
#  ('checkered', 0.41),
#  ('inarticulate', 0.41),
#  ('inattentive', 0.41),
#  ('excellent', 0.41),
#  ('easier', 0.41),
#  ('evasive', 0.41),
#  ('straggly', 0.41),
#  ('excitable', 0.41),
#  ('icelandic', 0.41),
#  ('bright', 0.41),
#  ('unquiet', 0.41),
#  ('unshod', 0.41),
#  ('moody', 0.41),
#  ('spiritual', 0.41),
#  ('granular', 0.41),
#  ('uncorrupted', 0.41),
#  ('frankish', 0.42),
#  ('organized', 0.42),
#  ('political', 0.42),
#  ('stolid', 0.42),
#  ('unwrinkled', 0.42),
#  ('spiked', 0.42),
#  ('dearborn', 0.42),
#  ('violet', 0.42),
#  ('sled', 0.42),
#  ('bizarre', 0.42),
#  ('slatted', 0.42),
#  ('incomparable', 0.42),
#  ('overhanging', 0.42),
#  ('spectacled', 0.42),
#  ('incautious', 0.42),
#  ('besieged', 0.42),
#  ('grander', 0.42),
#  ('outraged', 0.42),
#  ('complete', 0.42),
#  ('stingy', 0.42),
#  ('pernicious', 0.42),
#  ('imprisoned', 0.42),
#  ('complaisant', 0.42),
#  ('sleeveless', 0.42),
#  ('baffled', 0.42),
#  ('reasonable', 0.42),
#  ('gauzy', 0.42),
#  ('competent', 0.42),
#  ('collective', 0.42),
#  ('unpolished', 0.42),
#  ('avowed', 0.42),
#  ('obscure', 0.42),
#  ('vere', 0.42),
#  ('adjoining', 0.42),
#  ('lucky', 0.42),
#  ('momentous', 0.42),
#  ('mossy', 0.42),
#  ('chalky', 0.42),
#  ('softest', 0.42),
#  ('tuscan', 0.42),
#  ('shattered', 0.42),
#  ('soldierly', 0.42),
#  ('triangular', 0.42),
#  ('unsuitable', 0.42),
#  ('logical', 0.42),
#  ('elizabethan', 0.42),
#  ('liven', 0.42),
#  ('evangelical', 0.42),
#  ('flat', 0.42),
#  ('total', 0.42),
#  ('cornish', 0.42),
#  ('cylindrical', 0.42),
#  ('artistic', 0.42),
#  ('unanimous', 0.42),
#  ('unbroken', 0.42),
#  ('unborn', 0.42),
#  ('unbearable', 0.42),
#  ('unbaked', 0.42),
#  ('vitreous', 0.42),
#  ('unchanged', 0.42),
#  ('uncharitable', 0.42),
#  ('adaptable', 0.42),
#  ('prismatic', 0.42),
#  ('uncivil', 0.42),
#  ('prior', 0.42),
#  ('fairest', 0.42),
#  ('unarmed', 0.42),
#  ('unappeased', 0.42),
#  ('sidelong', 0.42),
#  ('causal', 0.42),
#  ('mixed', 0.42),
#  ('arrogant', 0.42),
#  ('shameful', 0.42),
#  ('spotless', 0.42),
#  ('unrivaled', 0.42),
#  ('lanky', 0.42),
#  ('vexatious', 0.42),
#  ('unerring', 0.42),
#  ('underhanded', 0.42),
#  ('unearned', 0.42),
#  ('undying', 0.42),
#  ('folded', 0.42),
#  ('damaged', 0.42),
#  ('affable', 0.42),
#  ('undue', 0.42),
#  ('negotiated', 0.42),
#  ('enameled', 0.42),
#  ('reddest', 0.42),
#  ('lateral', 0.42),
#  ('coarsest', 0.42),
#  ('observational', 0.42),
#  ('christlike', 0.42),
#  ('asleep', 0.42),
#  ('portuguese', 0.42),
#  ('titular', 0.42),
#  ('fleshy', 0.42),
#  ('naturalistic', 0.42),
#  ('braided', 0.42),
#  ('likely', 0.42),
#  ('divisional', 0.42),
#  ('preferable', 0.42),
#  ('naval', 0.42),
#  ('shamefaced', 0.42),
#  ('plush', 0.43),
#  ('imaginable', 0.43),
#  ('abstract', 0.43),
#  ('hebrew', 0.43),
#  ('plumb', 0.43),
#  ('armenian', 0.43),
#  ('speedier', 0.43),
#  ('warm', 0.43),
#  ('unripe', 0.43),
#  ('pleated', 0.43),
#  ('sainted', 0.43),
#  ('unsanitary', 0.43),
#  ('sober', 0.43),
#  ('unrecognized', 0.43),
#  ('prehistoric', 0.43),
#  ('austrian', 0.43),
#  ('inalienable', 0.43),
#  ('scattered', 0.43),
#  ('contrite', 0.43),
#  ('hoosier', 0.43),
#  ('preposterous', 0.43),
#  ('soapy', 0.43),
#  ('unsheltered', 0.43),
#  ('presbyterian', 0.43),
#  ('slower', 0.43),
#  ('artless', 0.43),
#  ('unsigned', 0.43),
#  ('split', 0.43),
#  ('hilly', 0.43),
#  ('contradictory', 0.43),
#  ('downy', 0.43),
#  ('phonetic', 0.43),
#  ('convivial', 0.43),
#  ('unburied', 0.43),
#  ('phenomenal', 0.43),
#  ('unvisited', 0.43),
#  ('uncontrollable', 0.43),
#  ('exalted', 0.43),
#  ('evident', 0.43),
#  ...]

# %%
[(word_list[i],target_change[i]) for i in np.flip(np.argsort(target_change))]
# Out:
# [('repellent', 1.0),
#  ('unmanned', 1.0),
#  ('catty', 1.0),
#  ('ignoble', 1.0),
#  ('gainful', 1.0),
#  ('minty', 1.0),
#  ('centrist', 0.99),
#  ('thrifty', 0.99),
#  ('renewable', 0.99),
#  ('tiered', 0.99),
#  ('scrumptious', 0.99),
#  ('sonic', 0.99),
#  ('chunky', 0.99),
#  ('discursive', 0.99),
#  ('stainless', 0.99),
#  ('chesty', 0.99),
#  ('moot', 0.99),
#  ('fuzzy', 0.99),
#  ('hazardous', 0.98),
#  ('regal', 0.98),
#  ('individualized', 0.98),
#  ('aging', 0.98),
#  ('amphibious', 0.98),
#  ('saccharine', 0.98),
#  ('eclectic', 0.98),
#  ('ambient', 0.97),
#  ('tannic', 0.97),
#  ('forthright', 0.97),
#  ('fabulous', 0.97),
#  ('diversified', 0.97),
#  ('cultured', 0.97),
#  ('turbulent', 0.97),
#  ('dusty', 0.97),
#  ('educable', 0.96),
#  ('wishful', 0.96),
#  ('interplanetary', 0.96),
#  ('formalized', 0.96),
#  ('phony', 0.96),
#  ('newfound', 0.96),
#  ('deft', 0.96),
#  ('adolescent', 0.96),
#  ('riveting', 0.96),
#  ('uninsured', 0.95),
#  ('literate', 0.95),
#  ('intramural', 0.95),
#  ('browner', 0.95),
#  ('sleazy', 0.95),
#  ('unmeasured', 0.95),
#  ('mercurial', 0.95),
#  ('extraterritorial', 0.95),
#  ('standardized', 0.95),
#  ('peaked', 0.95),
#  ('impeccable', 0.95),
#  ('immune', 0.95),
#  ('advanced', 0.95),
#  ('dirigible', 0.95),
#  ('muted', 0.95),
#  ('inelastic', 0.95),
#  ('adept', 0.94),
#  ('inedible', 0.94),
#  ('uncommitted', 0.94),
#  ('gassy', 0.94),
#  ('compliant', 0.94),
#  ('foregone', 0.94),
#  ('chipper', 0.94),
#  ('unlisted', 0.94),
#  ('scrawny', 0.94),
#  ('fledgling', 0.94),
#  ('foxy', 0.94),
#  ('massive', 0.94),
#  ('swashbuckling', 0.94),
#  ('chubby', 0.94),
#  ('hulking', 0.94),
#  ('transpacific', 0.94),
#  ('gullible', 0.9299999999999999),
#  ('homeless', 0.9299999999999999),
#  ('hefty', 0.9299999999999999),
#  ('interdenominational', 0.9299999999999999),
#  ('intercontinental', 0.9299999999999999),
#  ('tian', 0.9299999999999999),
#  ('crucial', 0.9299999999999999),
#  ('putative', 0.9299999999999999),
#  ('chauvinistic', 0.9299999999999999),
#  ('hectic', 0.9299999999999999),
#  ('ambulatory', 0.9299999999999999),
#  ('pivotal', 0.9299999999999999),
#  ('sassy', 0.9299999999999999),
#  ('illuminating', 0.9299999999999999),
#  ('hermetic', 0.9299999999999999),
#  ('sophisticated', 0.9299999999999999),
#  ('apoplectic', 0.9299999999999999),
#  ('belligerent', 0.9299999999999999),
#  ('spectral', 0.9299999999999999),
#  ('musky', 0.9299999999999999),
#  ('shoddy', 0.92),
#  ('dictatorial', 0.92),
#  ('emergent', 0.92),
#  ('cumulative', 0.92),
#  ('nuclear', 0.92),
#  ('canny', 0.92),
#  ('coeval', 0.92),
#  ('ionic', 0.92),
#  ('bossy', 0.92),
#  ('newborn', 0.92),
#  ('sensitized', 0.92),
#  ('resurgent', 0.92),
#  ('flipping', 0.92),
#  ('antisocial', 0.91),
#  ('soulful', 0.91),
#  ('cryptic', 0.91),
#  ('vegetarian', 0.91),
#  ('rootless', 0.91),
#  ('dizzy', 0.91),
#  ('stressful', 0.91),
#  ('mindless', 0.91),
#  ('unlit', 0.91),
#  ('tropic', 0.91),
#  ('unlovely', 0.91),
#  ('untitled', 0.91),
#  ('dolorous', 0.91),
#  ('composite', 0.91),
#  ('truant', 0.91),
#  ('cognizant', 0.91),
#  ('singular', 0.91),
#  ('auroral', 0.9),
#  ('aloof', 0.9),
#  ('frosty', 0.9),
#  ('specialised', 0.9),
#  ('onetime', 0.9),
#  ('contentious', 0.9),
#  ('disposable', 0.9),
#  ('sublimated', 0.9),
#  ('agonized', 0.9),
#  ('selfless', 0.9),
#  ('intangible', 0.9),
#  ('peppery', 0.9),
#  ('disabled', 0.9),
#  ('strapping', 0.9),
#  ('eastbound', 0.9),
#  ('rash', 0.9),
#  ('wry', 0.9),
#  ('indentured', 0.9),
#  ('coldwater', 0.9),
#  ('adamant', 0.9),
#  ('scenic', 0.9),
#  ('firsthand', 0.9),
#  ('tough', 0.9),
#  ('middling', 0.9),
#  ('unnumbered', 0.89),
#  ('elderly', 0.89),
#  ('devious', 0.89),
#  ('impressionistic', 0.89),
#  ('pygmy', 0.89),
#  ('squeaky', 0.89),
#  ('interracial', 0.89),
#  ('repro', 0.89),
#  ('leaky', 0.89),
#  ('murky', 0.89),
#  ('funded', 0.89),
#  ('unified', 0.89),
#  ('downright', 0.89),
#  ('superannuated', 0.89),
#  ('insensitive', 0.89),
#  ('unmoving', 0.89),
#  ('intriguing', 0.89),
#  ('husky', 0.89),
#  ('bonded', 0.89),
#  ('soporific', 0.89),
#  ('subtropical', 0.89),
#  ('cosmetic', 0.89),
#  ('inextinguishable', 0.89),
#  ('grisly', 0.89),
#  ('morbid', 0.89),
#  ('crass', 0.89),
#  ('oncoming', 0.89),
#  ('agile', 0.89),
#  ('psy', 0.89),
#  ('longtime', 0.88),
#  ('decentralized', 0.88),
#  ('fissured', 0.88),
#  ('homemade', 0.88),
#  ('reflective', 0.88),
#  ('naive', 0.88),
#  ('repatriated', 0.88),
#  ('noncommissioned', 0.88),
#  ('climactic', 0.88),
#  ('limber', 0.88),
#  ('voiceless', 0.88),
#  ('temperamental', 0.88),
#  ('scary', 0.88),
#  ('martian', 0.88),
#  ('disproportionately', 0.88),
#  ('mercenary', 0.88),
#  ('covert', 0.88),
#  ('trim', 0.88),
#  ('purposeful', 0.88),
#  ('porcine', 0.88),
#  ('communicative', 0.88),
#  ('fluent', 0.88),
#  ('interrogatory', 0.88),
#  ('perceptive', 0.88),
#  ('pudgy', 0.88),
#  ('shortest', 0.88),
#  ('adaptive', 0.88),
#  ('dirty', 0.88),
#  ('torrid', 0.88),
#  ('heartening', 0.88),
#  ('tantalizing', 0.87),
#  ('cen', 0.87),
#  ('consumptive', 0.87),
#  ('ambassadorial', 0.87),
#  ('fourfold', 0.87),
#  ('conciliatory', 0.87),
#  ('prearranged', 0.87),
#  ('negroid', 0.87),
#  ('compulsive', 0.87),
#  ('rudimentary', 0.87),
#  ('monolithic', 0.87),
#  ('schematic', 0.87),
#  ('neighborly', 0.87),
#  ('ic', 0.87),
#  ('livable', 0.87),
#  ('unwarned', 0.87),
#  ('unconstrained', 0.87),
#  ('dual', 0.87),
#  ('authoritarian', 0.87),
#  ('labyrinthine', 0.87),
#  ('demonic', 0.87),
#  ('unknowing', 0.87),
#  ('histrionic', 0.87),
#  ('outright', 0.87),
#  ('asthmatic', 0.87),
#  ('italianate', 0.87),
#  ('interpretative', 0.87),
#  ('overcast', 0.87),
#  ('vulnerable', 0.87),
#  ('nal', 0.87),
#  ('damming', 0.87),
#  ('responsive', 0.87),
#  ('harrowing', 0.87),
#  ('sixpenny', 0.87),
#  ('pubic', 0.87),
#  ('idealized', 0.87),
#  ('intertwining', 0.87),
#  ('omnivorous', 0.87),
#  ('overweight', 0.87),
#  ('neanderthal', 0.87),
#  ('revolving', 0.87),
#  ('gabby', 0.87),
#  ('melancholic', 0.87),
#  ('indigenous', 0.87),
#  ('subconscious', 0.86),
#  ('cloistered', 0.86),
#  ('hybrid', 0.86),
#  ('intolerant', 0.86),
#  ('interacting', 0.86),
#  ('jovian', 0.86),
#  ('dietetic', 0.86),
#  ('titanic', 0.86),
#  ('disordered', 0.86),
#  ('virulent', 0.86),
#  ('ailing', 0.86),
#  ('quadruple', 0.86),
#  ('pulverized', 0.86),
#  ('determinative', 0.86),
#  ('vic', 0.86),
#  ('vibrant', 0.86),
#  ('pseudo', 0.86),
#  ('tripartite', 0.86),
#  ('retaliatory', 0.86),
#  ('homing', 0.86),
#  ('desiccated', 0.86),
#  ('rarefied', 0.86),
#  ('honorable', 0.86),
#  ('paramount', 0.86),
#  ('brash', 0.86),
#  ('equine', 0.86),
#  ('caloric', 0.86),
#  ('ruthless', 0.86),
#  ('engrossed', 0.86),
#  ('tenacious', 0.86),
#  ('loth', 0.86),
#  ('roundabout', 0.86),
#  ('errant', 0.86),
#  ('immemorial', 0.86),
#  ('inspirational', 0.86),
#  ('acoustic', 0.86),
#  ('unaccompanied', 0.86),
#  ('unreconciled', 0.86),
#  ('perishable', 0.85),
#  ('adelphi', 0.85),
#  ('hearty', 0.85),
#  ('perfect', 0.85),
#  ('monopolistic', 0.85),
#  ('belike', 0.85),
#  ('bankrupt', 0.85),
#  ('amicable', 0.85),
#  ('imperative', 0.85),
#  ('beleaguered', 0.85),
#  ('episodic', 0.85),
#  ('eneral', 0.85),
#  ('hypodermic', 0.85),
#  ('neap', 0.85),
#  ('stalwart', 0.85),
#  ('worst', 0.85),
#  ('abrasive', 0.85),
#  ('elemental', 0.85),
#  ('electrochemical', 0.85),
#  ('uninspired', 0.85),
#  ('contemporary', 0.85),
#  ('befuddled', 0.85),
#  ('poignant', 0.85),
#  ('effete', 0.85),
#  ('jaunty', 0.85),
#  ('spare', 0.85),
#  ('effervescent', 0.85),
#  ('bubonic', 0.85),
#  ('tubercular', 0.85),
#  ('unconfined', 0.85),
#  ('rationalized', 0.85),
#  ('clandestine', 0.85),
#  ('flaccid', 0.85),
#  ('delectable', 0.85),
#  ('tarred', 0.85),
#  ('arty', 0.85),
#  ('loquacious', 0.85),
#  ('throaty', 0.85),
#  ('senile', 0.85),
#  ('tailored', 0.85),
#  ('restrictive', 0.85),
#  ('sexless', 0.85),
#  ('illicit', 0.85),
#  ('shoeless', 0.85),
#  ('fictional', 0.85),
#  ('discerning', 0.85),
#  ('interstellar', 0.85),
#  ('centralized', 0.85),
#  ('random', 0.85),
#  ('rancorous', 0.85),
#  ('promiscuous', 0.85),
#  ('sized', 0.85),
#  ('quasi', 0.85),
#  ('clashing', 0.84),
#  ('bovine', 0.84),
#  ('implicit', 0.84),
#  ('insular', 0.84),
#  ('threefold', 0.84),
#  ('imponderable', 0.84),
#  ('atavistic', 0.84),
#  ('compatible', 0.84),
#  ('gordian', 0.84),
#  ('benign', 0.84),
#  ('tacit', 0.84),
#  ('unperturbed', 0.84),
#  ('glib', 0.84),
#  ('beefy', 0.84),
#  ('tractable', 0.84),
#  ('canine', 0.84),
#  ('childless', 0.84),
#  ('bilingual', 0.84),
#  ('utopian', 0.84),
#  ('leisured', 0.84),
#  ('pragmatic', 0.84),
#  ('wifely', 0.84),
#  ('menial', 0.84),
#  ('exportable', 0.84),
#  ('flashy', 0.84),
#  ('expressive', 0.84),
#  ('migratory', 0.84),
#  ('festering', 0.84),
#  ('plentiful', 0.84),
#  ('salient', 0.84),
#  ('metric', 0.84),
#  ('sequestered', 0.84),
#  ('deferential', 0.84),
#  ('leprous', 0.84),
#  ('doctrinaire', 0.84),
#  ('helmeted', 0.84),
#  ('possessive', 0.84),
#  ('secret', 0.84),
#  ('heterogeneous', 0.84),
#  ('cramped', 0.84),
#  ('professorial', 0.84),
#  ('somber', 0.84),
#  ('nifty', 0.84),
#  ('volatile', 0.84),
#  ('nutty', 0.84),
#  ('faltering', 0.84),
#  ('sounder', 0.84),
#  ('antiseptic', 0.84),
#  ('optional', 0.84),
#  ('mundane', 0.84),
#  ('overriding', 0.84),
#  ('mous', 0.84),
#  ('counterfeit', 0.84),
#  ('eccentric', 0.84),
#  ('masterful', 0.84),
#  ('meteoric', 0.84),
#  ('discrete', 0.83),
#  ('fake', 0.83),
#  ('ual', 0.83),
#  ('hipped', 0.83),
#  ('inflexible', 0.83),
#  ('ratty', 0.83),
#  ('ironical', 0.83),
#  ('mesmeric', 0.83),
#  ('exotic', 0.83),
#  ('impish', 0.83),
#  ('nude', 0.83),
#  ('unlimited', 0.83),
#  ('nascent', 0.83),
#  ('myopic', 0.83),
#  ('effulgent', 0.83),
#  ('binary', 0.83),
#  ('haphazard', 0.83),
#  ('pennyroyal', 0.83),
#  ('boring', 0.83),
#  ('durable', 0.83),
#  ('mirrored', 0.83),
#  ('poached', 0.83),
#  ('meticulous', 0.83),
#  ('reconquest', 0.83),
#  ('unmapped', 0.83),
#  ('latest', 0.83),
#  ('jaundiced', 0.83),
#  ('hottest', 0.83),
#  ('frightening', 0.83),
#  ('ambivalent', 0.83),
#  ('thunderous', 0.83),
#  ('loudest', 0.83),
#  ('daffy', 0.83),
#  ('intoxicating', 0.83),
#  ('decadent', 0.83),
#  ('idyllic', 0.83),
#  ('horseless', 0.83),
#  ('floral', 0.83),
#  ('snide', 0.83),
#  ('runaway', 0.83),
#  ('stratified', 0.83),
#  ('vicarious', 0.8200000000000001),
#  ('decimal', 0.8200000000000001),
#  ('unimagined', 0.8200000000000001),
#  ('inexpressible', 0.8200000000000001),
#  ('antediluvian', 0.8200000000000001),
#  ('grudging', 0.8200000000000001),
#  ('pappy', 0.8200000000000001),
#  ('proprietary', 0.8200000000000001),
#  ('mezzanine', 0.8200000000000001),
#  ('exemplary', 0.8200000000000001),
#  ('debatable', 0.8200000000000001),
#  ('grubby', 0.8200000000000001),
#  ('clearest', 0.8200000000000001),
#  ('deaf', 0.8200000000000001),
#  ('briny', 0.8200000000000001),
#  ('exigent', 0.8200000000000001),
#  ('brackish', 0.8200000000000001),
#  ('bended', 0.8200000000000001),
#  ('ancillary', 0.8200000000000001),
#  ('benevolent', 0.8200000000000001),
#  ('simulated', 0.8200000000000001),
#  ('expansive', 0.8200000000000001),
#  ('tentative', 0.8200000000000001),
#  ('ingenuous', 0.8200000000000001),
#  ('imperialistic', 0.8200000000000001),
#  ('trenchant', 0.8200000000000001),
#  ('transoceanic', 0.8200000000000001),
#  ('transient', 0.8200000000000001),
#  ('transatlantic', 0.8200000000000001),
#  ('imaginary', 0.8200000000000001),
#  ('rabid', 0.8200000000000001),
#  ('ramshackle', 0.8200000000000001),
#  ('tottering', 0.8200000000000001),
#  ('unlike', 0.8200000000000001),
#  ('retrospective', 0.8200000000000001),
#  ('stringed', 0.8200000000000001),
#  ('refractory', 0.8200000000000001),
#  ('unmodified', 0.8200000000000001),
#  ('feline', 0.8200000000000001),
#  ('constitutive', 0.8200000000000001),
#  ('irreversible', 0.8200000000000001),
#  ('southernmost', 0.8200000000000001),
#  ('foregoing', 0.8200000000000001),
#  ('med', 0.8200000000000001),
#  ('provocative', 0.8200000000000001),
#  ('aquatic', 0.8200000000000001),
#  ('hilarious', 0.8200000000000001),
#  ('maximal', 0.8200000000000001),
#  ('wormy', 0.8200000000000001),
#  ('sorrowful', 0.8200000000000001),
#  ('basic', 0.8200000000000001),
#  ('believable', 0.81),
#  ('noisome', 0.81),
#  ('orphaned', 0.81),
#  ('sultry', 0.81),
#  ('ornate', 0.81),
#  ('unilateral', 0.81),
#  ('forgiving', 0.81),
#  ('kinder', 0.81),
#  ('energetic', 0.81),
#  ('overdue', 0.81),
#  ('unitary', 0.81),
#  ('beguiling', 0.81),
#  ('knotty', 0.81),
#  ('equinoctial', 0.81),
#  ('super', 0.81),
#  ('encyclopedic', 0.81),
#  ('figurative', 0.81),
#  ('periodic', 0.81),
#  ('cherubic', 0.81),
#  ('prim', 0.81),
#  ('rotten', 0.81),
#  ('trusty', 0.81),
#  ('finite', 0.81),
#  ('roofless', 0.81),
#  ('demure', 0.81),
#  ('innovating', 0.81),
#  ('retroactive', 0.81),
#  ('permissive', 0.81),
#  ('chic', 0.81),
#  ('refined', 0.81),
#  ('topical', 0.81),
#  ('tolerant', 0.81),
#  ('remote', 0.81),
#  ('diagrammatic', 0.81),
#  ('retentive', 0.81),
#  ('charnel', 0.81),
#  ('meditative', 0.81),
#  ('chaotic', 0.81),
#  ('prescient', 0.81),
#  ('generalized', 0.81),
#  ('ducky', 0.81),
#  ('sibilant', 0.81),
#  ('synthetic', 0.81),
#  ('populist', 0.81),
#  ('candid', 0.81),
#  ('sedentary', 0.81),
#  ('infantile', 0.81),
#  ('carefree', 0.81),
#  ('mercial', 0.81),
#  ('dissonant', 0.81),
#  ('lighthearted', 0.81),
#  ('informal', 0.81),
#  ('disruptive', 0.81),
#  ('chambered', 0.81),
#  ('populous', 0.81),
#  ('ital', 0.81),
#  ('unsung', 0.81),
#  ('unobtrusive', 0.81),
#  ('warlike', 0.81),
#  ('alcoholic', 0.81),
#  ('appalachian', 0.81),
#  ('wordless', 0.81),
#  ('virginal', 0.81),
#  ('wakeful', 0.81),
#  ('worldwide', 0.81),
#  ('wouldbe', 0.81),
#  ('aggregate', 0.81),
#  ('nonpartisan', 0.8),
#  ('stunning', 0.8),
#  ('inviolable', 0.8),
#  ('comparable', 0.8),
#  ('daft', 0.8),
#  ('constrained', 0.8),
#  ('indelible', 0.8),
#  ('sparse', 0.8),
#  ('neural', 0.8),
#  ('graceless', 0.8),
#  ('soy', 0.8),
#  ('neurotic', 0.8),
#  ('columbian', 0.8),
#  ('plenipotentiary', 0.8),
#  ('creepy', 0.8),
#  ('anecdotal', 0.8),
#  ('shasta', 0.8),
#  ('dissolute', 0.8),
#  ('sour', 0.8),
#  ('raucous', 0.8),
#  ('subliminal', 0.8),
#  ('funniest', 0.8),
#  ('buttery', 0.8),
#  ('inert', 0.8),
#  ('callous', 0.8),
#  ('awash', 0.8),
#  ('elephantine', 0.8),
#  ('bookish', 0.8),
#  ('typhoid', 0.8),
#  ('tumultuous', 0.8),
#  ('absorbent', 0.8),
#  ('choppy', 0.8),
#  ('flexible', 0.8),
#  ('palestinian', 0.8),
#  ('palsied', 0.8),
#  ('telephonic', 0.8),
#  ('taut', 0.8),
#  ('synchronous', 0.8),
#  ('monochromatic', 0.8),
#  ('sweaty', 0.8),
#  ('sunburnt', 0.8),
#  ('expeditious', 0.8),
#  ('unmatched', 0.8),
#  ('specialized', 0.8),
#  ('fleeting', 0.8),
#  ('proletarian', 0.8),
#  ('malleable', 0.8),
#  ('unmade', 0.8),
#  ('unmixed', 0.8),
#  ('racy', 0.8),
#  ('marginal', 0.8),
#  ('unnamed', 0.8),
#  ('marriageable', 0.8),
#  ('ambrosial', 0.8),
#  ('fittest', 0.8),
#  ('rowdy', 0.8),
#  ('prudential', 0.8),
#  ('prone', 0.8),
#  ('vestal', 0.8),
#  ('scholarly', 0.79),
#  ('moneyed', 0.79),
#  ('aseptic', 0.79),
#  ('marauding', 0.79),
#  ('tangled', 0.79),
#  ('secondary', 0.79),
#  ('marital', 0.79),
#  ('armored', 0.79),
#  ('surreptitious', 0.79),
#  ('iconoclastic', 0.79),
#  ('interurban', 0.79),
#  ('mordant', 0.79),
#  ('intimidating', 0.79),
#  ('retrogressive', 0.79),
#  ('introspective', 0.79),
#  ('intrusive', 0.79),
#  ('derelict', 0.79),
#  ('cyclonic', 0.79),
#  ('demonstrative', 0.79),
#  ('pungent', 0.79),
#  ('tense', 0.79),
#  ('fruity', 0.79),
#  ('achievable', 0.79),
#  ('viscous', 0.79),
#  ('brawny', 0.79),
#  ('esoteric', 0.79),
#  ('direct', 0.79),
#  ('imperturbable', 0.79),
#  ('cancerous', 0.79),
#  ('barbaric', 0.79),
#  ('avid', 0.79),
#  ('cannibalistic', 0.79),
#  ('celibate', 0.79),
#  ('illimitable', 0.79),
#  ('cellular', 0.79),
#  ('typical', 0.79),
#  ('unmitigated', 0.79),
#  ('twofold', 0.79),
#  ('fecund', 0.79),
#  ('trashy', 0.79),
#  ('hourly', 0.79),
#  ('atomic', 0.79),
#  ('delinquent', 0.79),
#  ('undeterred', 0.79),
#  ('appreciable', 0.79),
#  ('forceful', 0.79),
#  ('anticipatory', 0.79),
#  ('neuter', 0.79),
#  ('appointive', 0.79),
#  ('jeffersonian', 0.79),
#  ('cosmological', 0.79),
#  ('cosmopolitan', 0.79),
#  ('flamboyant', 0.79),
#  ('watertight', 0.79),
#  ('sordid', 0.79),
#  ('kosher', 0.79),
#  ('forwarding', 0.79),
#  ('fluctuating', 0.79),
#  ('seasoned', 0.79),
#  ('metaphorical', 0.79),
#  ('distributive', 0.79),
#  ('stale', 0.79),
#  ('squat', 0.79),
#  ('piercing', 0.79),
#  ('niggling', 0.79),
#  ('fossilized', 0.79),
#  ('plenary', 0.79),
#  ('costlier', 0.78),
#  ('elysian', 0.78),
#  ('overlapping', 0.78),
#  ('serial', 0.78),
#  ('aural', 0.78),
#  ('diminutive', 0.78),
#  ('sizable', 0.78),
#  ('presumptive', 0.78),
#  ('forensic', 0.78),
#  ('gallant', 0.78),
#  ('tutoring', 0.78),
#  ('crude', 0.78),
#  ('doleful', 0.78),
#  ('visionary', 0.78),
#  ('fearful', 0.78),
#  ('indigent', 0.78),
#  ('embattled', 0.78),
#  ('knobby', 0.78),
#  ('rancid', 0.78),
#  ('infertile', 0.78),
#  ('cartesian', 0.78),
#  ('mediocre', 0.78),
#  ('optimistic', 0.78),
#  ('kinetic', 0.78),
#  ('palatable', 0.78),
#  ('witty', 0.78),
#  ('windward', 0.78),
#  ('monogamous', 0.78),
#  ('melodramatic', 0.78),
#  ('crisp', 0.78),
#  ('deliberate', 0.78),
#  ('piratical', 0.78),
#  ('disobedient', 0.78),
#  ('splendiferous', 0.78),
#  ('sardonic', 0.78),
#  ('cocky', 0.78),
#  ('urbane', 0.78),
#  ('homicidal', 0.78),
#  ('dour', 0.78),
#  ('stable', 0.78),
#  ('strongest', 0.78),
#  ('armoured', 0.78),
#  ('idealistic', 0.78),
#  ('patronymic', 0.78),
#  ('idiotic', 0.78),
#  ('queer', 0.78),
#  ('rueful', 0.78),
#  ('paternalistic', 0.78),
#  ('tempestuous', 0.78),
#  ('militant', 0.78),
#  ('protean', 0.78),
#  ('civilized', 0.78),
#  ('agonizing', 0.78),
#  ('tidy', 0.78),
#  ('quintus', 0.78),
#  ('rabbinical', 0.78),
#  ('eerie', 0.78),
#  ('multicolored', 0.78),
#  ('secessionist', 0.78),
#  ('flimsy', 0.78),
#  ('barefooted', 0.78),
#  ('enticing', 0.78),
#  ('belated', 0.78),
#  ('unpaid', 0.78),
#  ('bayous', 0.78),
#  ('nether', 0.78),
#  ('nihilistic', 0.78),
#  ('newer', 0.78),
#  ('impending', 0.78),
#  ('bootless', 0.78),
#  ('gossipy', 0.78),
#  ('unlearned', 0.78),
#  ('lax', 0.77),
#  ('current', 0.77),
#  ('customary', 0.77),
#  ('weakest', 0.77),
#  ('legendary', 0.77),
#  ('needy', 0.77),
#  ('lavish', 0.77),
#  ('deadly', 0.77),
#  ('shrill', 0.77),
#  ('sizzling', 0.77),
#  ('metallurgical', 0.77),
#  ('overt', 0.77),
#  ('dissenting', 0.77),
#  ('seasonable', 0.77),
#  ('medicinal', 0.77),
#  ('unattended', 0.77),
#  ('uncaring', 0.77),
#  ('robust', 0.77),
#  ('indecent', 0.77),
#  ('unbound', 0.77),
#  ('prurient', 0.77),
#  ('elusive', 0.77),
#  ('noisy', 0.77),
#  ('infinitesimal', 0.77),
#  ('sensitive', 0.77),
#  ('ostensible', 0.77),
#  ('autonomous', 0.77),
#  ('facetious', 0.77),
#  ('scholastic', 0.77),
#  ('dismal', 0.77),
#  ('anguished', 0.77),
#  ('unofficial', 0.77),
#  ('multiple', 0.77),
#  ('copyrighted', 0.77),
#  ('creaky', 0.77),
#  ('unexploded', 0.77),
#  ('mistrustful', 0.77),
#  ('hysterical', 0.77),
#  ('tattered', 0.77),
#  ('tasteless', 0.77),
#  ('ial', 0.77),
#  ('patriarchal', 0.77),
#  ('neighboring', 0.77),
#  ('tained', 0.77),
#  ('equable', 0.77),
#  ('dumb', 0.77),
#  ('hardest', 0.77),
#  ('supernormal', 0.77),
#  ('closest', 0.77),
#  ('neighbouring', 0.77),
#  ('interpretive', 0.77),
#  ('monkish', 0.77),
#  ('complimentary', 0.77),
#  ('monosyllabic', 0.77),
#  ('poisonous', 0.77),
#  ('assertive', 0.77),
#  ('kantian', 0.77),
#  ('emaciated', 0.77),
#  ('chummy', 0.77),
#  ('plump', 0.77),
#  ('tillable', 0.77),
#  ('unorthodox', 0.77),
#  ('sorry', 0.77),
#  ('hyperbolic', 0.77),
#  ('tenfold', 0.77),
#  ('apologetic', 0.77),
#  ('instantaneous', 0.77),
#  ('inc', 0.77),
#  ('itinerant', 0.77),
#  ('heartbreaking', 0.77),
#  ('acquisitive', 0.77),
#  ('tepid', 0.77),
#  ('demagogic', 0.77),
#  ('exhilarating', 0.77),
#  ('digital', 0.77),
#  ('endearing', 0.77),
#  ('virtual', 0.77),
#  ('worthwhile', 0.77),
#  ('derogatory', 0.77),
#  ('gusty', 0.77),
#  ('olympic', 0.77),
#  ('quaint', 0.77),
#  ('generating', 0.77),
#  ('wagnerian', 0.77),
#  ('quizzical', 0.77),
#  ('devastating', 0.76),
#  ('chastened', 0.76),
#  ('statuesque', 0.76),
#  ('stenographic', 0.76),
#  ('prenatal', 0.76),
#  ('merced', 0.76),
#  ('indissoluble', 0.76),
#  ('appetizing', 0.76),
#  ('unlighted', 0.76),
#  ('crimean', 0.76),
#  ('yere', 0.76),
#  ('prac', 0.76),
#  ('abusive', 0.76),
#  ('telepathic', 0.76),
#  ('leaded', 0.76),
#  ('leafed', 0.76),
#  ('vicious', 0.76),
#  ('gastronomic', 0.76),
#  ('unimproved', 0.76),
#  ('unincorporated', 0.76),
#  ('newtonian', 0.76),
#  ('bearable', 0.76),
#  ('secondhand', 0.76),
#  ('nonchalant', 0.76),
#  ('gaping', 0.76),
#  ('breakneck', 0.76),
#  ('seagoing', 0.76),
#  ('strident', 0.76),
#  ('developmental', 0.76),
#  ('grizzly', 0.76),
#  ('stagnant', 0.76),
#  ('impromptu', 0.76),
#  ('motherless', 0.76),
#  ('fullest', 0.76),
#  ('ful', 0.76),
#  ('hypersensitive', 0.76),
#  ('frustrating', 0.76),
#  ('planetary', 0.76),
#  ('adhesive', 0.76),
#  ('unpaved', 0.76),
#  ('federated', 0.76),
#  ('brisk', 0.76),
#  ('illegitimate', 0.76),
#  ('genital', 0.76),
#  ('unexamined', 0.76),
#  ('broad', 0.76),
#  ('jerky', 0.76),
#  ('polemical', 0.76),
#  ('chilling', 0.76),
#  ('circumscribed', 0.76),
#  ('unheralded', 0.76),
#  ('tragic', 0.76),
#  ('traditional', 0.76),
#  ('thal', 0.76),
#  ('portly', 0.76),
#  ('credential', 0.76),
#  ('incontinent', 0.76),
#  ('jaded', 0.76),
#  ('astir', 0.76),
#  ('constructive', 0.76),
#  ('smarter', 0.76),
#  ('fulsome', 0.76),
#  ('ponderous', 0.76),
#  ('contemplative', 0.76),
#  ('northeastern', 0.76),
#  ('dotty', 0.76),
#  ('headless', 0.76),
#  ('unobstructed', 0.76),
#  ('orthopedic', 0.76),
#  ('lineal', 0.76),
#  ('protuberant', 0.76),
#  ('celestial', 0.76),
#  ('roseate', 0.76),
#  ('deliberative', 0.76),
#  ('classy', 0.76),
#  ('opulent', 0.76),
#  ('sweltering', 0.76),
#  ('providential', 0.76),
#  ('lifelong', 0.76),
#  ('bygone', 0.76),
#  ('grim', 0.76),
#  ('depository', 0.76),
#  ('perilous', 0.76),
#  ('impressive', 0.76),
#  ('peachy', 0.76),
#  ('puny', 0.76),
#  ('looser', 0.76),
#  ('autocratic', 0.76),
#  ('sappy', 0.76),
#  ('subtle', 0.76),
#  ('amorous', 0.76),
#  ('sanguinary', 0.76),
#  ('saintly', 0.75),
#  ('dowdy', 0.75),
#  ('comfy', 0.75),
#  ('parochial', 0.75),
#  ('orbital', 0.75),
#  ('epochal', 0.75),
#  ('unsurprised', 0.75),
#  ('fantastical', 0.75),
#  ('oversupply', 0.75),
#  ('subversive', 0.75),
#  ('quickest', 0.75),
#  ('discretionary', 0.75),
#  ('diagnostic', 0.75),
#  ('unmarked', 0.75),
#  ('vaudeville', 0.75),
#  ('multiform', 0.75),
#  ('adroit', 0.75),
#  ('workmanlike', 0.75),
#  ('hyphenated', 0.75),
#  ('pioneering', 0.75),
#  ('elegiac', 0.75),
#  ('cosy', 0.75),
#  ('intimate', 0.75),
#  ('cial', 0.75),
#  ('soundless', 0.75),
#  ('graded', 0.75),
#  ('pleasurable', 0.75),
#  ('discontinuous', 0.75),
#  ('intermediate', 0.75),
#  ('adamantine', 0.75),
#  ('anthropomorphic', 0.75),
#  ('vindictive', 0.75),
#  ('convalescent', 0.75),
#  ('odd', 0.75),
#  ('palliative', 0.75),
#  ('dialectical', 0.75),
#  ('roomy', 0.75),
#  ('admonitory', 0.75),
#  ('bored', 0.75),
#  ('assorted', 0.75),
#  ('fecal', 0.75),
#  ('heady', 0.75),
#  ('immobile', 0.75),
#  ('canonical', 0.75),
#  ('contemporaneous', 0.75),
#  ('rasping', 0.75),
#  ('superb', 0.75),
#  ('hegelian', 0.75),
#  ('tolerable', 0.75),
#  ('thieving', 0.75),
#  ('yellowing', 0.75),
#  ('purgative', 0.75),
#  ('sinister', 0.75),
#  ('comprehensive', 0.75),
#  ('sallow', 0.75),
#  ('fiduciary', 0.75),
#  ('mellow', 0.75),
#  ('sturdy', 0.75),
#  ('invertebrate', 0.75),
#  ('cute', 0.75),
#  ('concerted', 0.75),
#  ('wealthier', 0.75),
#  ('numb', 0.75),
#  ('galvanic', 0.75),
#  ('tasty', 0.75),
#  ('revengeful', 0.75),
#  ('beady', 0.75),
#  ('horrific', 0.75),
#  ...]

# %%
word = 'tasteful'
ind = word2ind[word]
k = 100

nn_origin = nn_origin_array[ind][:k]
nn_target = nn_array[ind][:k]
intersect = np.intersect1d(nn_origin,nn_target)

print('1890 : ',[word_list[i] for i in nn_origin])
print('1990 : ',[word_list[i] for i in nn_target])
print('Intersect : ',[word_list[i] for i in intersect])
print('Change : ',1-len(intersect)/len(nn_origin))
# Out:
# 1890 :  ['ingenious', 'shrewd', 'lifelike', 'masterly', 'plucky', 'praiseworthy', 'elegant', 'felicitous', 'talented', 'judicious', 'serviceable', 'pugnacious', 'instructive', 'astute', 'mediocre', 'farreaching', 'delusive', 'salutary', 'bigoted', 'estimable', 'advantageous', 'quarrelsome', 'energetic', 'sumptuous', 'imprudent', 'meritorious', 'regrettable', 'shortsighted', 'skilful', 'sagacious', 'intractable', 'mischievous', 'lovable', 'ostentatious', 'voracious', 'equidistant', 'forceful', 'quaint', 'munificent', 'elaborate', 'tortuous', 'exhaustive', 'admirable', 'laudable', 'delicate', 'improvident', 'pleasing', 'fastidious', 'irrepressible', 'deplorable', 'meager', 'licentious', 'skillful', 'hospitable', 'meagre', 'sturdy', 'zealous', 'generous', 'costly', 'fallible', 'anomalous', 'lenient', 'antiquated', 'parsimonious', 'multifarious', 'strenuous', 'discouraging', 'irate', 'ennobling', 'corpulent', 'indiscreet', 'illogical', 'cumbersome', 'impecunious', 'intricate', 'gaudy', 'fervent', 'diminutive', 'boastful', 'disreputable', 'concentric', 'equable', 'indecent', 'humiliating', 'farsighted', 'equivocal', 'thoroughgoing', 'shabby', 'tenuous', 'cozy', 'heterogeneous', 'arduous', 'beneficent', 'vicious', 'despicable', 'gigantic', 'uninteresting', 'impressive', 'enterprising', 'rude']
# 1990 :  ['ingenious', 'fearsome', 'miserly', 'succinct', 'plucky', 'prolific', 'astute', 'sumptuous', 'exuberant', 'pithy', 'punctilious', 'terse', 'ostentatious', 'likable', 'quaint', 'lighthearted', 'erudite', 'circumspect', 'classy', 'farsighted', 'droll', 'trenchant', 'intricate', 'munificent', 'stylish', 'heartening', 'amateurish', 'tactful', 'enigmatic', 'unimaginative', 'haphazard', 'conciliatory', 'expansive', 'easygoing', 'provocative', 'inelegant', 'praiseworthy', 'lovable', 'roomy', 'regrettable', 'bellicose', 'devious', 'forthright', 'salubrious', 'parsimonious', 'lifelike', 'voracious', 'tawdry', 'poignant', 'gruesome', 'horrifying', 'ferocious', 'ghoulish', 'loquacious', 'mirthful', 'prudish', 'multifarious', 'rapacious', 'boisterous', 'enthralling', 'bigoted', 'startling', 'skilful', 'masterly', 'sensational', 'decrepit', 'penurious', 'strident', 'playful', 'infrequent', 'audacious', 'uninspiring', 'nonchalant', 'secretive', 'fiendish', 'selfless', 'pitiful', 'indecorous', 'judicious', 'shrewd', 'pugnacious', 'opulent', 'genteel', 'austere', 'indefinable', 'subtle', 'mediocre', 'exquisite', 'mindless', 'imprudent', 'stupendous', 'effusive', 'salutary', 'generous', 'multitudinous', 'tactless', 'aimless', 'inflexible', 'shortsighted', 'instructive']
# Intersect :  ['astute', 'bigoted', 'farsighted', 'generous', 'imprudent', 'ingenious', 'instructive', 'intricate', 'judicious', 'lifelike', 'lovable', 'masterly', 'mediocre', 'multifarious', 'munificent', 'ostentatious', 'parsimonious', 'plucky', 'praiseworthy', 'pugnacious', 'quaint', 'regrettable', 'salutary', 'shortsighted', 'shrewd', 'skilful', 'sumptuous', 'voracious']
# Change :  0.72

# %%
# Out:
# 0.7
